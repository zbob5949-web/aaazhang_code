# %%
#计算三角形面积
def s(a,b):
    S=float((a*b)/2)
    print(f"三角形面积为:{S}")
a=int(input("请输入底边长："))
b=int(input("请输入高："))
s(a,b)
# Out:
# 请输入底边长： 5
# 请输入高： 3
# 三角形面积为:7.5

# %%
#统计元音字母个数
def YY(S1):
    a=S1.count('a')+S1.count('A')
    e=S1.count('e')+S1.count('E')  
    i=S1.count('i')+S1.count('I')
    o=S1.count('o')+S1.count('O')
    u=S1.count('u')+S1.count('U')
    print(f'a出现了{a}次')
    print(f'e出现了{e}次')
    print(f'i出现了{i}次')
    print(f'o出现了{o}次')
    print(f'u出现了{u}次')


s='fj;oiu;esjhiow;hgurthrowhrisheiohwhfuwkghrn[osdfhs'
YY(s)
# Out:
# a出现了0次
# e出现了2次
# i出现了4次
# o出现了5次
# u出现了3次

# %%
#计算成绩最高，最低，平均分
def score(list,n):
    list.sort()
    print(f"最高分{list[n-1]}")
    print(f"最低分：{list[0]}")
    total=sum(list)
    avg=total/n
    print(f"平均分为：{avg}")
n=10
list_1=[]
for i in range(n):
    num=int(input("请输入学生成绩："))
    list_1.append(num)
score(list_1,n)
# Out:
# 请输入学生成绩： 11
# 请输入学生成绩： 22
# 请输入学生成绩： 33
# 请输入学生成绩： 44
# 请输入学生成绩： 55
# 请输入学生成绩： 66
# 请输入学生成绩： 77
# 请输入学生成绩： 889
# 请输入学生成绩： 100
# 请输入学生成绩： 22
# 最高分889
# 最低分：11
# 平均分为：131.9

# %%
#全局变量在函数中使用
num=100
def function():
    global num
    num=10
    print(num)
function()
# Out:
# 10

# %%
#位置加关键字传参
def stu_function(name,age,city='南京',gender='男'):
    print(f"{name}, {age}, {city}, {gender}")

Age=input("年龄：")
Name=input("姓名：")
stu_function(Name,Age)
# Out:
# 年龄： 16
# 姓名： 张三
# 张三, 16, 南京, 男

# %%
#不定长参数
def calc_function(*args,**kwargs):
    min_data=min(args)
    max_data=max(args)
    avg_data=sum(args)/len(args)

    if kwargs.get('round') is not None:
        avg_data=round(avg_data,kwargs.get('round'))
        if kwargs.get('print'):
            print(f'最小值为：{min_data},最大值为：{max_data},平均值为：{avg_data}')                   
calc_function(1,3,7,45,6,round=3,print=True)
# Out:
# 最小值为：1,最大值为：45,平均值为：12.4

# %%
#匿名函数
add=lambda x,y :x+y
print(add(10,20))
# Out:
# 30

# %%
#字符串长度排序
data_list=['c','c++','java','javascript']
data_list.sort(key=lambda item:len(item),reverse=True)
print(data_list)
# Out:
# ['javascript', 'java', 'c++', 'c']

# %%
#n的阶乘
def jc(n):
    if n==1:
        print('1')
    else:
        result=1
        for i in range(1,n+1):
            result*=i
        print(result)
jc(10)
# Out:
# 3628800

# %%
class stu:
    def __init__(self,brand,name):
        self.brand=brand
        self.name=name
    def say_hello(self):
        print(f"我叫{self.name}")
c1=stu('bmw','张三')
print(c1.brand)
c1.say_hello()
# Out:
# bmw
# 我叫张三

# %%
class stu:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def __add__(self,other):
        return stu(self.a+other.a,self.b+other.b)
    def __str__(self):
        return f"{self.a+self.b}"
s1=stu(3,4)
s2=stu(5,6)
print(s1)
print(s1+s2)
# Out:
# 7
# 18

# %%
class Animal:
    def speak(self)
        pass
class Dog(Animal)        
    def speak(self)
        print("汪汪")
def make_speak(self)        
    animal speak

# %%
class stu:
    def __init_(self,name,yw,sx,yy):
        self.name=name
        self.yw=yw
        self.sx=sx
        self.yy=yy
    def _str__(self):
        return f"姓名：{self.name},语文：{slef.yw},数学：{self.sx},英语：{self.yy}"

    #修改
    def update_score(self,yw,sx,yy):
        if yw is not None:
            self.yw=yw
        if sx is not None:
            self.sx=sx
        if yy is not None:
            self.yy=yy


class stum:
    def __init__(self):
        self.student_list=[]
#添加        
    def add_stu(self,stu):
        name=input("请输入学生姓名：")
        for s in sutdent_list:
            if s.name==name:
                print("请重新输入！")
        yw=input("请输入语文成绩：")
        yw=input("请输入数学成绩：")
        yw=input("请输入英语成绩：")
        if 0<yw<=100 and 0<sx<=100 and 0<yy<=100:
            student=stu(name,yw,sx,yy)
            self.student_list.append(student)
            print("添加完毕！")

#修改
    def update_score(self):
        name=input("请输入要修改的学生姓名：")
        for s in student_list:
            if self.name==name:
                print(f"当前成绩：{s}")
        yw=input("请输入修改后的语文成绩：")
        sx=input("请输入修改后的数学成绩：")
        yy=input("请输入修改后的英语成绩：")

    if 0<yw<=100 and 0<sx<=100 and 0<yy<=100:
        s.updata_score(yw,sx,yy)
        print(f"修改后成绩：{s}")
        return
    else:
        print("成绩应该在0～100")
        return
#删除
    def delete_score(self):
        name=input("请输入要修改的学生姓名：")
        for s in student_list:
            if self.name==name:
                self.student_list.remove(s)
                print("删除成功！") 
            else:
                print("删除失败！")
#查询
    def get_score(self):
        name=input("请输入要修改的学生姓名：")
        for s in student_list:
            if self.name==name:
                print(f"学生信息：{s}") 
            else:
                print("未找到！")

#显示
    def list_score(self):
         for s in student_list:
            print(s)

#主界面
    def run(self):
        print("#############欢迎进入学生管理系统################")
        while True:    
            print("请输入要执行的操作：1:添加/n 2.修改/n 3.删除/n 4.查询/n 5.显示/n 6.退出")
        choice=input("请输入要执行的操作：")      
        match choice:
            case"1":
                self.add_student()
            case"2":
                self.update_score()
            case"3":
                self.delete_score()
            case"4":
                self.get_score()
            case"5":
                self.list_score()
            case"6":
                break



#测试
if __name__=='__main__':
    stu_m=stum()
    stu_m.run()
# Out:
#   Cell In[12], line 50
#     return
#     ^
# SyntaxError: 'return' outside function

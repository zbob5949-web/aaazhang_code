# %%
#检查输入邮箱 是否一个@ 至少一个 .
email=input("请输入您的邮箱：")
if email.count('@')==1 and email.count('.')>=1:
    print("邮箱格式正确")
else:
    print("请重新输入")
# Out:
# 请输入您的邮箱： 3383321967@qq.com
# 邮箱格式正确

# %%
#交换a b
a=10 
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
#学生成绩管理系统
YW_list=[33,90,89,78,56]
SX_list=[34,66,77,88,99]
YY_list=[44,56,77,33,22]
sum_list=[]
avg_list=[]
for i in range(5):
    total=YW_list[i]+SX_list[i]+YY_list[i]
    sum_list.append(total)
    avg=sum_list[i]/3
    avg_list.append(avg)
print(f"王明的总分为{sum_list[0]},平均分为{avg_list[0]:.2f}")
print(f"张三的总分为{sum_list[1]},平均分为{avg_list[1]:.2f}")
print(f"韩立的总分为{sum_list[2]},平均分为{avg_list[2]:.2f}")
print(f"李飞雨的总分为{sum_list[3]},平均分为{avg_list[3]:.2f}")
print(f"武思的总分为{sum_list[4]},平均分为{avg_list[4]:.2f}")
# Out:
# 王明的总分为111,平均分为37.00
# 张三的总分为212,平均分为70.67
# 韩立的总分为243,平均分为81.00
# 李飞雨的总分为199,平均分为66.33
# 武思的总分为177,平均分为59.00

# %%
#集合
a_set={"张三","里斯","王五","六六"}
b_set={"张三","黄芪"}
c_set={"刘备","关羽","张飞","王五","张三"}
d_set={"张三","里斯","六六","王五"}

cd_set=c_set.intersection (d_set)
print(cd_set)
abcd_set=a_set.intersection(b_set.intersection(c_set.intersection(d_set)))
print(abcd_set)
b_no_c_set=b_set.difference(c_set)
print(b_no_c_set)
abcd_list=[*a_set,*b_set,*c_set,*d_set]
abcd_set=a_set|b_set|c_set|d_set
for s in abcd_set:
    print(f"{s}一共选了{abcd_list.count(s)}门课程")
# Out:
# {'张三', '王五'}
# {'张三'}
# {'黄芪'}
# 关羽一共选了1门课程
# 黄芪一共选了1门课程
# 里斯一共选了2门课程
# 王五一共选了3门课程
# 张三一共选了4门课程
# 刘备一共选了1门课程
# 张飞一共选了1门课程
# 六六一共选了2门课程

# %%
#字典
print("欢迎使用购物车管理系统！")
print("########## 购物车系统 #########")
print("          1.添加购物车         ")
print("          2.修改购物车         ")
print("          3.删除购物车         ")
print("          4.查询购物车         ")
print("          5.退出购物车         ")
print("#############################")
shopping_cart={}
while True:
    choice=input("请输入要执行的操作：")
    match choice:
        case"1":
            goods_name=input("请输入商品名称：")
            goods_price=float(input("请输入商品价格："))
            goods_counts=int(input("请输入商品数量："))


            if goods_name in shopping_cart:
                print("商品已经存在，请重新输入")
            else:
                shopping_cart[goods_name]={"price":goods_price,"counts":goods_counts}
            print("商品添加完毕！")
        case"2":
            goods_name=input("请输入最新的商品名称：")
            goods_price=float(input("请输入最新的商品价格："))
            goods_counts=int(input("请输入最新的商品数量："))
            if goods_name not in shopping_cart:
                priint("商品不存在，请重新输入！")
            else:
                shopping_cart[goods_name]={"price":goods_price,"counts":goods_counts}
            print("商品添加完毕！")
        case"3":
            goos_name=input("请输入要删除的商品：")
            if goods_name not in shopping_cart:
                priint("商品不存在，请重新输入！")
            else:
               del shopping_cart[goods_name]
            print("商品删除完毕！")
        
        case"4":
            for goods_name in shopping_cart:
                goods_info=shopping_cart[goods_name]
                print(f"商品名称：{goods_name}，商品价格：{goods_info['price']}，商品数量：{goods_info['counts']}")
        case"5":
            break
        case  _:
            print("非法操作，不支持")
# Out:
# 欢迎使用购物车管理系统！
# ########## 购物车系统 #########
#           1.添加购物车
#           2.修改购物车
#           3.删除购物车
#           4.查询购物车
#           5.退出购物车
# #############################
# 请输入要执行的操作： 1
# 请输入商品名称： Ipad
# 请输入商品价格： 388
# 请输入商品数量： 1
# 商品添加完毕！
# 请输入要执行的操作： 4
# 商品名称：Ipad，商品价格：388.0，商品数量：1
